# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
# !pip install pymysql
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:Nupur%40123@localhost:3306/classicmodels')

# %%
df = pd.read_sql_table("employees",engine)
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
query = ''' SELECT customers.customerName,customers.salesRepEmployeeNumber,customers.customerNumber,employees.employeeNumber,employees.firstName
FROM customers INNER JOIN employees
ON customers.salesRepEmployeeNumber=employees.employeeNumber;
 '''
# Execute the query
df = pd.read_sql_query(query,engine)
df
# Out:
#                       customerName  salesRepEmployeeNumber  customerNumber  \
# 0                Atelier graphique                    1370             103
# 1               Signal Gift Stores                    1166             112
# 2       Australian Collectors, Co.                    1611             114
# 3                La Rochelle Gifts                    1370             119
# 4               Baane Mini Imports                    1504             121
# ..                             ...                     ...             ...
# 95    Motor Mint Distributors Inc.                    1323             486
# 96        Signal Collectibles Ltd.                    1165             487
# 97  Double Decker Gift Stores, Ltd                    1501             489
# 98            Diecast Collectables                    1188             495
# 99               Kelly's Gift Shop                    1612             496
#
#     employeeNumber firstName
# 0             1370    Gerard
# ...

# %%
query = ''' SELECT customers.customerName,customers.customerNumber
 FROM customers;
 
 '''
# Execute the query
df = pd.read_sql_query(query,engine)
df
# Out:
#                        customerName  customerNumber
# 0                 Atelier graphique             103
# 1                Signal Gift Stores             112
# 2        Australian Collectors, Co.             114
# 3                 La Rochelle Gifts             119
# 4                Baane Mini Imports             121
# ..                              ...             ...
# 117    Motor Mint Distributors Inc.             486
# 118        Signal Collectibles Ltd.             487
# 119  Double Decker Gift Stores, Ltd             489
# 120            Diecast Collectables             495
# 121               Kelly's Gift Shop             496
#
# [122 rows x 2 columns]

# %%
df2 = pd.DataFrame({
    'customerNumber': [6, 7, 8],
    'customerName': ["Rohit", "Ram", "Om"],
    'contactLastName': ["Sharma", "Verma", "Yadav"],
    'contactFirstName': ["Rohit", "Ram", "Om"],
    'phone': ["+91-9999999999"] * 3,
    'addressLine1': ["123 Main St"] * 3,
    'city': ["Mumbai"] * 3,
    'country': ["India"] * 3,
    'salesRepEmployeeNumber': [1166] * 3,  # must be valid employeeNumber from employees table
    'creditLimit': [50000.00] * 3
})

# %%
# enter value in sql
df.to_sql(
    name='customers',
    con=engine,
    index=False,
    if_exists='append',
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File d:\python\pandas\myenv\Lib\site-packages\sqlalchemy\engine\base.py:1932, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1931     if not evt_handled:
# -> 1932         self.dialect.do_executemany(
#    1933             cursor,
#    1934             str_statement,
#    1935             effective_parameters,
#    1936             context,
#    1937         )
#    1938 elif not effective_parameters and context.no_parameters:
#
# File d:\python\pandas\myenv\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:172, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     171 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 172     rowcount = cursor.executemany(statement, parameters)
#     173     if context is not None:
#
# ...

# %%
ff = pd.read_sql_table('customers',engine)
ff
# Out:
#      customerNumber                    customerName contactLastName  \
# 0                 6                           Rohit          Sharma
# 1                 7                             Ram           Verma
# 2                 8                              Om           Yadav
# 3               103               Atelier graphique         Schmitt
# 4               112              Signal Gift Stores            King
# ..              ...                             ...             ...
# 120             486    Motor Mint Distributors Inc.         Salazar
# 121             487        Signal Collectibles Ltd.          Taylor
# 122             489  Double Decker Gift Stores, Ltd           Smith
# 123             495            Diecast Collectables          Franco
# 124             496               Kelly's Gift Shop         Snowden
#
#     contactFirstName           phone        addressLine1 addressLine2  \
# 0              Rohit  +91-9999999999         123 Main St         None
# ...
